# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyentuanphong0510/AI/blob/main/Aktbaitapolop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import copy
from heapq import heappush, heappop

#Thuật giải Akt vào bài toán 8 puzzle(n=3)
#Giả sử n=4
n=4
# 4 vị trí tương ứng left, right, bottom,top
rows=[1,0,-1,0]
cols=[0,-1,0,1]
#tạo một lớp hàng đợi
class priorityQueue:
    def __init__(self):
      self.heap=[]
    def push(self,key):
      heappush(self.heap,key)
    def pop(self):
      return heappop(self.heap)
    def empty(self):
        if not self.heap:
            return True
        else:
            return False

class nodes:
    def __init__(self,parent,mats,empty_tile_posi,costs,levels):
        self.parent=parent
        self.mats=mats
        self.empty_tile_posi=empty_tile_posi
        self.costs=costs
        self.levels=levels
    def __lt__(self,nxt):
        return self.costs < nxt.costs


    def calculateCosts(mats,final)->int:
        count=0
        for i in range(n):
          for j in range(n):
            # Exclude the empty tile (0) from mismatch count
            if mats[i][j] != 0 and mats[i][j] != final[i][j]:
              count +=1
        return count


    def newNodes(mats,empty_tile_posi,new_empty_tile_posi,levels,parent,final)->"nodes":
        new_mats=copy.deepcopy(mats)
        x1=empty_tile_posi[0]
        y1=empty_tile_posi[1]
        x2=new_empty_tile_posi[0]
        y2=new_empty_tile_posi[1]
        new_mats[x1][y1], new_mats[x2][y2]=new_mats[x2][y2],new_mats[x1][y1]
        costs = nodes.calculateCosts(new_mats,final)

        new_nodes=nodes(parent,new_mats,new_empty_tile_posi,costs,levels)

        return new_nodes

    def printMatsrix(mats):
        for i in range(n):
          for j in range(n):
            print("%d " % (mats[i][j]),end = " ")
          print()


    def isSafe(x,y):
      return x>=0 and x<n and y>=0 and y<n


    def printPath(root):
      if root==None:
        return

      nodes.printPath(root.parent)
      nodes.printMatsrix(root.mats)
      print()


    def solve(initial,empty_tile_posi,final):
      pq=priorityQueue()
      costs=nodes.calculateCosts(initial,final)
      root=nodes(None,initial,empty_tile_posi,costs,0)
      pq.push(root)

      while not pq.empty():
        minimum=pq.pop()
        if minimum.costs==0:
          nodes.printPath(minimum)
          return

        for i in range(n):
          new_tile_posi=[minimum.empty_tile_posi[0]+rows[i],minimum.empty_tile_posi[1]+cols[i],]
          if nodes.isSafe(new_tile_posi[0],new_tile_posi[1]):
            child=nodes.newNodes(minimum.mats,minimum.empty_tile_posi,new_tile_posi,minimum.levels+1,minimum,final)
            pq.push(child)

# Initial state, final state, and empty tile position for the 8-puzzle problem
initial=[[ 1,2,3,9],
           [5,6,10,0],
           [7,8,11,4] ]
final=[[1,2,3,9],
       [5,8,6,10],
       [0,7,4,11] ] # Changed to list for consistency
empty_tile_posi=[1,2]

nodes.solve(initial,empty_tile_posi,final)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_11092/4024852021.py in <cell line: 0>()
#     103 empty_tile_posi=[1,2]
#     104
# --> 105 nodes.solve(initial,empty_tile_posi,final)
#
# /tmp/ipykernel_11092/4024852021.py in solve(initial, empty_tile_posi, final)
#      78     def solve(initial,empty_tile_posi,final):
#      79       pq=priorityQueue()
# ---> 80       costs=nodes.calculateCosts(initial,final)
#      81       root=nodes(None,initial,empty_tile_posi,costs,0)
#      82       pq.push(root)
#
# /tmp/ipykernel_11092/4024852021.py in calculateCosts(mats, final)
#      38           for j in range(n):
#      39             # Exclude the empty tile (0) from mismatch count
# ---> 40             if mats[i][j] != 0 and mats[i][j] != final[i][j]:
#      41               count +=1
#      42         return count
#
# IndexError: list index out of range
